# %% [markdown]
# <a href="https://colab.research.google.com/github/bhanusri158/IBM-PROJECT/blob/main/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
from keras.datasets import reuters

# %%
(train_X, train_Y), (test_X, test_Y) = reuters.load_data(num_words=10000)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/reuters.npz
# 2110848/2110848 [==============================] - 1s 0us/step

# %%
import numpy as np
from keras.utils import to_categorical

def OneHotEncoding_fn(ReutersData, dimension=10000):

    OneHotEncoded_Data = np.zeros((len(ReutersData), dimension))
    for i, sequence in enumerate(ReutersData):

        OneHotEncoded_Data[i, sequence] = 1.
    return OneHotEncoded_Data

x_train = OneHotEncoding_fn(train_X)
x_test = OneHotEncoding_fn(test_X)

y_train = to_categorical(train_Y)
y_test = to_categorical(test_Y)

# %%
from keras import models
from keras import layers
from keras import regularizers

model = models.Sequential()
#model.add(layers.Dense(64, activation='relu', input_shape=(10000,)))
#model.add(layers.Dense(64, kernel_regularizer=regularizers.l1(0.001), activation='relu', input_shape=(10000,)))
#model.add(layers.Dense(64, kernel_regularizer=regularizers.l2(0.01), activation='relu', input_shape=(10000,)))
model.add(layers.Dense(64, kernel_regularizer=regularizers.l1_l2(l1=0.001, l2=0.01), activation='relu', input_shape=(10000,)))

#model.add(layers.Dense(64, activation='relu'))
#model.add(layers.Dense(64, kernel_regularizer=regularizers.l1(0.001), activation='relu'))
#model.add(layers.Dense(64, kernel_regularizer=regularizers.l2(0.01), activation='relu'))
model.add(layers.Dense(64, kernel_regularizer=regularizers.l1_l2(l1=0.001, l2=0.01), activation='relu'))

model.add(layers.Dense(46, activation='softmax'))

# %%
from keras import optimizers
from keras import losses
from keras import metrics

X_validation = x_train[:800]
X_train_without_val = x_train[800:]
y_validation = y_train[:800]
y_train_without_val = y_train[800:]


model.compile(optimizer=optimizers.RMSprop(learning_rate=0.001, rho=0.9),
             loss=losses.categorical_crossentropy,
             metrics=[metrics.categorical_accuracy])

history = model.fit(X_train_without_val,
                    y_train_without_val,
                    epochs=25,
                    batch_size=512,
                    validation_data=(X_validation,y_validation))
# Out:
# Epoch 1/25
# 16/16 [==============================] - 2s 88ms/step - loss: 7.0863 - categorical_accuracy: 0.4813 - val_loss: 3.6392 - val_categorical_accuracy: 0.5575
# Epoch 2/25
# 16/16 [==============================] - 1s 85ms/step - loss: 3.3534 - categorical_accuracy: 0.5596 - val_loss: 3.1092 - val_categorical_accuracy: 0.5850
# Epoch 3/25
# 16/16 [==============================] - 1s 87ms/step - loss: 3.0363 - categorical_accuracy: 0.5922 - val_loss: 2.8800 - val_categorical_accuracy: 0.6288
# Epoch 4/25
# 16/16 [==============================] - 1s 55ms/step - loss: 2.8506 - categorical_accuracy: 0.6255 - val_loss: 2.7434 - val_categorical_accuracy: 0.6413
# Epoch 5/25
# 16/16 [==============================] - 1s 52ms/step - loss: 2.7134 - categorical_accuracy: 0.6450 - val_loss: 2.5987 - val_categorical_accuracy: 0.6687
# Epoch 6/25
# 16/16 [==============================] - 1s 52ms/step - loss: 2.5971 - categorical_accuracy: 0.6600 - val_loss: 2.5067 - val_categorical_accuracy: 0.6787
# Epoch 7/25
# 16/16 [==============================] - 1s 52ms/step - loss: 2.4978 - categorical_accuracy: 0.6695 - val_loss: 2.4143 - val_categorical_accuracy: 0.6875
# Epoch 8/25
# 16/16 [==============================] - 1s 52ms/step - loss: 2.4155 - categorical_accuracy: 0.6791 - val_loss: 2.3625 - val_categorical_accuracy: 0.6800
# Epoch 9/25
# 16/16 [==============================] - 1s 51ms/step - loss: 2.3410 - categorical_accuracy: 0.6844 - val_loss: 2.2756 - val_categorical_accuracy: 0.6862
# Epoch 10/25
# 16/16 [==============================] - 1s 49ms/step - loss: 2.2806 - categorical_accuracy: 0.6866 - val_loss: 2.2273 - val_categorical_accuracy: 0.6825
# Epoch 11/25
# 16/16 [==============================] - 1s 53ms/step - loss: 2.2341 - categorical_accuracy: 0.6850 - val_loss: 2.1733 - val_categorical_accuracy: 0.6950
# Epoch 12/25
# 16/16 [==============================] - 1s 52ms/step - loss: 2.1836 - categorical_accuracy: 0.6919 - val_loss: 2.1440 - val_categorical_accuracy: 0.6938
# Epoch 13/25
# 16/16 [==============================] - 1s 51ms/step - loss: 2.1527 - categorical_accuracy: 0.6926 - val_loss: 2.1039 - val_categorical_accuracy: 0.6950
# Epoch 14/25
# 16/16 [==============================] - 1s 52ms/step - loss: 2.1203 - categorical_accuracy: 0.6947 - val_loss: 2.1028 - val_categorical_accuracy: 0.6888
# Epoch 15/25
# 16/16 [==============================] - 1s 55ms/step - loss: 2.0968 - categorical_accuracy: 0.6935 - val_loss: 2.0598 - val_categorical_accuracy: 0.6950
# Epoch 16/25
# 16/16 [==============================] - 1s 93ms/step - loss: 2.0674 - categorical_accuracy: 0.6946 - val_loss: 2.0496 - val_categorical_accuracy: 0.6963
# Epoch 17/25
# 16/16 [==============================] - 1s 88ms/step - loss: 2.0493 - categorical_accuracy: 0.6954 - val_loss: 2.0125 - val_categorical_accuracy: 0.6988
# Epoch 18/25
# 16/16 [==============================] - 1s 51ms/step - loss: 2.0257 - categorical_accuracy: 0.6985 - val_loss: 2.0120 - val_categorical_accuracy: 0.6913
# Epoch 19/25
# 16/16 [==============================] - 1s 53ms/step - loss: 2.0080 - categorical_accuracy: 0.6980 - val_loss: 1.9873 - val_categorical_accuracy: 0.7000
# Epoch 20/25
# 16/16 [==============================] - 1s 50ms/step - loss: 1.9886 - categorical_accuracy: 0.7000 - val_loss: 1.9804 - val_categorical_accuracy: 0.7038
# Epoch 21/25
# 16/16 [==============================] - 1s 50ms/step - loss: 1.9747 - categorical_accuracy: 0.7014 - val_loss: 1.9471 - val_categorical_accuracy: 0.6988
# Epoch 22/25
# 16/16 [==============================] - 1s 53ms/step - loss: 1.9574 - categorical_accuracy: 0.7011 - val_loss: 1.9623 - val_categorical_accuracy: 0.7050
# Epoch 23/25
# 16/16 [==============================] - 1s 51ms/step - loss: 1.9480 - categorical_accuracy: 0.7008 - val_loss: 1.9331 - val_categorical_accuracy: 0.6975
# Epoch 24/25
# 16/16 [==============================] - 1s 52ms/step - loss: 1.9312 - categorical_accuracy: 0.7022 - val_loss: 1.9095 - val_categorical_accuracy: 0.7013
# Epoch 25/25
# 16/16 [==============================] - 1s 50ms/step - loss: 1.9195 - categorical_accuracy: 0.7020 - val_loss: 1.9103 - val_categorical_accuracy: 0.6975

# %%
import matplotlib.pyplot as plt

history_dict = history.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']

epochs = range(1, len(loss_values) + 1)

plt.plot(epochs, loss_values, 'g--', label='Training loss')
plt.plot(epochs, val_loss_values, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
plt.clf()
acc_values = history_dict['categorical_accuracy']
val_acc_values = history_dict['val_categorical_accuracy']
plt.plot(epochs, acc_values, 'g--', label='Training Accuracy')
plt.plot(epochs, val_acc_values, 'r', label='Validation Accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
